# %% [markdown]
# # Deep learning intro
# ## General intro to deep learning
# - focuses on
# - perceptron = neuron equivalent
#
# ## Topics
# ### Artificial neural network: focuses on using the perceptron for binary classification. The foundation of deep learning
# ### Deep neural network
# ### TensorFlow:
# - the most popular library for ML to build models
# - developed by google
# - Keras is a 'gui' for tensorflow
# ### Model optimization and performance improvements
# - optimization of models to get the most accurate result
# ### Stacking with neural netowrks
# ### Convolutional neural networks
# - using deep learning in computer vision
# ### Stacking with neural networks
# ### Transfer Learning
# - utilizing transfer learning to enhance performance and efficiency
# ### Object detection
#
# ## Recurrent neural networks (RNN)
# - to solve time series problems and for NLP
#
# ### Transformer models for NLP:
# - this is the "T" in Chat-GPT
#
# ### Autoencoders
# - for general dimension reduction
#
# ### PyTorch
# - optimized tensor library
#
# ![image.png](attachment:image.png)
